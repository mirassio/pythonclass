# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba78f799-2811-44dd-a6da-421b3cb95566" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba78f799-2811-44dd-a6da-421b3cb95566">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile('olist_data.zip', 'r') as zip_ref:
    zip_ref.extractall('olist_data')  # Extracts to a folder named 'olist_data'

# %%
import pandas as pd

# Load each dataset
order_items = pd.read_csv('olist_data/olist_order_items_dataset.csv')
products = pd.read_csv('olist_data/olist_products_dataset.csv')
sellers = pd.read_csv('olist_data/olist_sellers_dataset.csv')
category_translation = pd.read_csv('olist_data/product_category_name_translation.csv')
customers = pd.read_csv('olist_data/olist_customers_dataset.csv')
reviews = pd.read_csv('olist_data/olist_order_reviews_dataset.csv')
geolocation = pd.read_csv('olist_data/olist_geolocation_dataset.csv')
orders = pd.read_csv('olist_data/olist_orders_dataset.csv')
payments = pd.read_csv('olist_data/olist_order_payments_dataset.csv')

# %% [markdown]
# You are an expert data scientist and strategic consultant. You are given the following data.Data description and dictionaries: Data is composed of 9 DataFrames described in detail below:
#
# Dataframe 1:
# Dataframe 1 name: products;
# Dataframe 1 description: this dataset includes data about the products sold by Olist;
# Dataframe 1 size: 9 columns, 32951 rows;
# Dataframe 1 data dictionary:
# product_id (str) unique product identifier;
# product_category_name (str) root category of product, in Portuguese,
# product_name_lenght (float64) number of characters extracted from the product name;
# product_description_lenght (float64) number of characters
# extracted from the product description;
# product_photos_qty (float64) number of product published photos;
# product_weight_g (float64) product weight measured in grams;
# product_length_cm (float64) product length measured in centimeters;
# product_height_cm (float64) product height measured in centimeters;
# product_width_cm (float64) product width measured in centimeters.
#
# Dataframe 2:
# Dataframe 2 name: category_translation;
# Dataframe 2 description: translates the product_category_name to English;
# Dataframe 2 size: 2 columns, 71 rows;
# Dataframe 2 data dictionary:
# product_category_name (str) category name in Portuguese;
# product_category_name_english (str) category name in English.
#
# Dataframe 3:
# Dataframe 3 name: customers;
# Dataframe 3 description: this dataset has information about the customers
# and their location, use it to identify unique customers in the orders dataset
# and to find the orders delivery location;
# Dataframe 3 size: 4 columns, 99441 rows;
# Dataframe 3 data dictionary:
# customer_id (str) key to the orders dataset, each order has a unique customer_id;
# customer_zip_code_prefix (int64) first five digits of customer ZIP code;
# customer_city (str) customer city name;
# customer_state (str) customer state.
#
# Dataframe 4
# Dataframe 4 name: orders;
# Dataframe 4 description: this is the core dataset, from each order you might
# find all other information;
# Dataframe 4 size: 7 columns, 99441 rows;
# Dataframe 4 data dictionary:
# order_id (str) unique identifier of an order;
# customer_id (str) key to the customer dataset, each order has a unique customer_id;
# order_status (str) reference to the order status, delivered, shipped, etc;
# order_purchase_timestamp (str) shows the purchase timestamp;
# order_approved_at (str) shows the payment approval timestamp;
# order_delivered_carrier_date (str) shows the order posting
# timestamp, when it was handled to the logistic partner;
# order_delivered_customer_date (str) shows the actual order
# delivery date to the customer.
# order_estimated_delivery_date (str) shows the estimated
# delivery date that was informed to customer at the purchase moment.
#
# Dataframe 5:
# Dataframe 5 name: order_items;
# Dataframe 5 description: this dataset includes data about the items pur-
# chased within each order;
# Dataframe 5 size: 7 columns, 112650 rows;
# Dataframe 5 data dictionary:
# order_id (str) order unique identifier;
# order_item_id (int64) sequential number identifying number of items
# included in the same order;
# product_id (str) product unique identifier;
# seller_id (str) seller unique identifier;
# shipping_limit_date (str) shows the seller shipping limit date for han-
# dling the order over to the logistic partner;
# price (float64) item price;
# freight_value (float64) item freight value item (if an order has more
# than one item the freight value is splitted between items);
#
# Dataframe 6:
# Dataframe 6 name: payments;
# Dataframe 6 description: data about the items purchased within each order;
# Dataframe 6 size: 5 columns, 103886 rows;
# Dataframe 6 data dictionary:
# order_id (str) unique identifier of an order;
# payment_sequential (int64) a customer may pay an order with more than
# one payment method. If he does so, a sequence will be created to differen-
# tiate them;
# payment_type (str) method of payment chosen by the customer;
# payment_installments (int64) number of installments chosen by the customer;
# payment_value (float64) transaction value;
#
# Dataframe 7:
# Dataframe 7 name: reviews;
# Dataframe 7 description: this dataset includes data about the reviews made
# by the customers, after a customer purchases the product from Olist Store a
# seller gets notified to fulfill that order, once the customer receives the prod-
# uct, or the estimated delivery date is due, the customer gets a satisfaction
# survey by email where he can give a note for the purchase experience and
# write down some comments;
# Dataframe 7 size: 7 columns and 99224 rows;
# Dataframe 7 data dictionary:
# review_id (str) unique review identifier;
# order_id (str) unique order identifier;
# review_score (int64) note ranging from 1 to 5 given by the customer on
# a satisfaction survey;
# review_comment_title (str) comment title from the review left by the
# customer, in Portuguese;
# review_comment_message (str) comment message from the review left by
# the customer, in Portuguese;
# review_creation_date (timestamp) shows the date in which the satis-
# faction survey was sent to the customer;
# review_answer_timestamp (timestamp) shows satisfaction survey answer timestamp.
#
# Dataframe 8:
# Dataframe 8 name: sellers;
# Dataframe 8 description: this dataset includes data about the sellers that fulfilled orders made at Olist, use it to find the seller location and to identify which seller fulfilled each product;
# Dataframe 8 size: Dataframe sellers has 4 columns and 3095 rows;
# Dataframe 8 data dictionary:
# seller_id (str) seller unique identifier;
# seller_zip_code_prefix (int64) first 5 digits of seller ZIP code;
# seller_city (str) seller city name;
# seller_state (str) seller state.
#
# Dataframe 9:
# Dataframe 9 name: geolocation;
# Dataframe 9 description: this dataset includes longitude and latitude of zip codes of brazil;
# Dataframe 9 size: Dataframe geolocation has 5 columns and 100000 rows;
# Dataframe 9 data dictionary:
# geolocation_lat (float64) geolocation latitude;
# geolocation_lng (float64) geolocation longitude;
# geolocation_zip_code_prefix (int64) first 5 digits of ZIP code;
# geolocation_city (str)  city;
# geolocation_state (str) state.
#
# I will give you tasks and you will write python code

# %% [markdown]
# ![image_31.png](data:image/png;base64,...)

# %% [markdown]
# #Customer Acquisition

# %% [markdown]
# write python code to identify the top 5 states generating new customers. After that make interactive time series map showing contribution of each of this 5 states separately by month

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# write python code to identify the top 5 product categories generating new customers. After that make interactive time series map showing contribution of each of this 5 product categories separately by month

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Product analysis

# %% [markdown]
# write python code to investigate which product categories have highest profit margin (price - freight_value). Only for those categories that have at least 100 orders

# %%
# Out:
# Top 10 product categories by average profit margin (>=100 orders):
#                product_category_name   avg_margin  order_count
# 62                               pcs  1049.885862          203
# 29                eletrodomesticos_2   431.586387          238
# 0          agro_industria_e_comercio   314.560708          212
# 31                   eletroportateis   257.184580          679
# 45             instrumentos_musicais   254.206456          680
# 72                    telefonia_fixa   208.125720          264
# 25  construcao_ferramentas_seguranca   188.790825          194
# 67                relogios_presentes   184.354824         5991
# 19                      climatizacao   162.544545          297
# 26                        cool_stuff   145.219112         3796
# /tmp/ipython-input-1263696391.py:33: FutureWarning:
#
#
#
# ...

# %% [markdown]
# write python code to investigate which product categories have lowest profit margin (price - freight_value). Only for those categories that have at least 100 orders

# %%
# Out:
# Top 10 product categories with lowest average profit margin (>=100 orders):
#              product_category_name  avg_margin  order_count
# 6                 artigos_de_natal   36.415163          153
# 2                alimentos_bebidas   38.386655          278
# 30                     eletronicos   41.080022         2767
# 1                        alimentos   43.377216          510
# 10                         bebidas   44.030211          379
# 49                 livros_tecnicos   55.479401          267
# 71                       telefonia   55.544937         4545
# 39  fashion_underwear_e_moda_praia   58.208855          131
# 33     fashion_bolsas_e_acessorios   59.760483         2031
# 38         fashion_roupa_masculina   65.495530          132
# /tmp/ipython-input-1546301852.py:32: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# write python code to investigate which product categories have highest profit volume (price - freight_value). Only for those categories that have at least 100 orders

# %%
# Out:
# Top 10 product categories by total profit volume (>=100 orders):
#      product_category_name  total_profit  order_count
# 67      relogios_presentes    1104469.75         5991
# 11            beleza_saude    1076114.61         9670
# 13         cama_mesa_banho     832295.64        11115
# 32           esporte_lazer     819441.46         8641
# 44  informatica_acessorios     764636.24         7827
# 54        moveis_decoracao     557013.19         8334
# 26              cool_stuff     551251.75         3796
# 8               automotivo     500055.90         4235
# 73   utilidades_domesticas     486099.55         6964
# 12              brinquedos     406520.65         4117
# /tmp/ipython-input-500327385.py:32: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# write python code to divide all product_description_lenght into three categories: short, medium, long. after that investigate if product length categories impact review score. use violin plot

# %%
# Out:
# /tmp/ipython-input-1028700576.py:23: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /tmp/ipython-input-1028700576.py:29: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Average review score by product description category:
#   description_category  review_score
# 0                short      4.007533
# 1               medium      4.054970
# 2                 long      4.053061

# %% [markdown]
# write python code to investigate if product_photos_qty impact review score. use violin plot

# %%
# Out:
# /tmp/ipython-input-3111547716.py:34: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# write python code to investigate product categories that are frequently bought together. make a bar plot of popular pairs

# %%
# Out:
# /tmp/ipython-input-4085576932.py:44: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # Logistic Optimization

# %% [markdown]
# write python code to find if on time delivery has impact on review score

# %%
# Out:
# Average review score by delivery status:
#    on_time  review_score
# 0    False      2.348192
# 1     True      4.293578

# %% [markdown]
# write python code to find if on time delivery has impact on review score. use violin plot

# %%
# Out:
# /tmp/ipython-input-3953274022.py:23: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# I want to find states that have high orders volume and high delivery delays. Make a scatter plot of order volume vs delivery delays.

# %% [markdown]
# #Understanding freight cost

# %% [markdown]
# write python code to investigate how product weight impact freight_value. use hexbin plot

# %% [markdown]
# write python code to investigate how product volume impact freight_value. use hexbin plot

# %% [markdown]
# #Seller analytics

# %% [markdown]
# write python code to leave only top 100 sellers by order volume. make a scatterplot of average review score vs revenue for these sellers

# %%
# Out:
# /tmp/ipython-input-3477239921.py:28: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.

# %% [markdown]
# write python code to investigate regions where customers to sellers ratio is large. make an interactive plot

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
